# %%
import sys
sys.path.append('../')
import utils
# %matplotlib inline

# %%
test_loader = utils.mnist_loader(train=False)
# Out:
# ...
# Processing...
# Done!

# %%
data, target = next(iter(test_loader))

# %%
utils.plot_mnist(data.numpy(), (5, 10))

# %%
# Out:
# torch.Size([1, 28, 28])
